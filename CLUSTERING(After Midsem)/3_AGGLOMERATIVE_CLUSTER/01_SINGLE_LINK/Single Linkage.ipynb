# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

# %% [markdown]
# # Euclidean Distance

# %%
def euclidean_distance(p1, p2):
    return np.sqrt(np.sum((p1 - p2) ** 2))

# %% [markdown]
# # Single Linkage Distance

# %%
def single_linkage_distance(cluster1, cluster2, data):

    min_dist = float("inf")

    for i in cluster1:
        for j in cluster2:
            dist = euclidean_distance(data[i], data[j])

            if dist < min_dist:
                min_dist = dist

    return min_dist

# %% [markdown]
# # Function to Print Distance Matrix

# %%
def print_distance_matrix(clusters, data):

    keys = list(clusters.keys())

    matrix = []

    for i in keys:
        row = []
        for j in keys:

            if i == j:
                row.append(0)
            else:
                dist = single_linkage_distance(clusters[i], clusters[j], data)
                row.append(round(dist,2))

        matrix.append(row)

    labels = [str(tuple(clusters[k])) for k in keys]

    df = pd.DataFrame(matrix, index=labels, columns=labels)

    print("\nDistance Matrix")
    print(df)

# %% [markdown]
# # Single Linkage

# %%
def single_linkage(data):

    n = len(data)

    clusters = {i:[i] for i in range(n)}

    next_cluster_id = n
    linkage_matrix = []

    step = 1

    while len(clusters) > 1:

        print(f"\n========== STEP {step} ==========")

        print_distance_matrix(clusters, data)

        keys = list(clusters.keys())

        min_dist = float("inf")
        pair = None

        for i in range(len(keys)):
            for j in range(i+1,len(keys)):

                c1 = clusters[keys[i]]
                c2 = clusters[keys[j]]

                dist = single_linkage_distance(c1,c2,data)

                if dist < min_dist:
                    min_dist = dist
                    pair = (keys[i],keys[j])

        c1,c2 = pair

        new_cluster = clusters[c1] + clusters[c2]

        row = [c1,c2,min_dist,len(new_cluster)]
        linkage_matrix.append(row)

        print(f"\nMerging clusters {clusters[c1]} and {clusters[c2]}")
        print(f"Distance = {round(min_dist,2)}")

        del clusters[c1]
        del clusters[c2]

        clusters[next_cluster_id] = new_cluster
        next_cluster_id += 1

        step += 1

    return np.array(linkage_matrix)

# %% [markdown]
# # Dataset

# %%
data = np.array([
    [1,2],
    [2,3],
    [8,8],
    [9,10],
    [25,30]
])

# %%
Z = single_linkage(data)

print("\nFinal Linkage Matrix")
print(Z)
# Out:
# ========== STEP 1 ==========
#
# Distance Matrix
#        (0,)   (1,)   (2,)   (3,)   (4,)
# (0,)   0.00   1.41   9.22  11.31  36.88
# (1,)   1.41   0.00   7.81   9.90  35.47
# (2,)   9.22   7.81   0.00   2.24  27.80
# (3,)  11.31   9.90   2.24   0.00  25.61
# (4,)  36.88  35.47  27.80  25.61   0.00
#
# Merging clusters [0] and [1]
# Distance = 1.41
#
# ========== STEP 2 ==========
#
# Distance Matrix
#          (2,)   (3,)   (4,)  (0, 1)
# (2,)     0.00   2.24  27.80    7.81
# (3,)     2.24   0.00  25.61    9.90
# (4,)    27.80  25.61   0.00   35.47
# (0, 1)   7.81   9.90  35.47    0.00
#
# Merging clusters [2] and [3]
# Distance = 2.24
#
# ========== STEP 3 ==========
#
# Distance Matrix
#          (4,)  (0, 1)  (2, 3)
# (4,)     0.00   35.47   25.61
# (0, 1)  35.47    0.00    7.81
# (2, 3)  25.61    7.81    0.00
#
# Merging clusters [0, 1] and [2, 3]
# Distance = 7.81
#
# ========== STEP 4 ==========
#
# Distance Matrix
#                (4,)  (0, 1, 2, 3)
# (4,)           0.00         25.61
# (0, 1, 2, 3)  25.61          0.00
#
# Merging clusters [4] and [0, 1, 2, 3]
# Distance = 25.61
#
# Final Linkage Matrix
# [[ 0.          1.          1.41421356  2.        ]
#  [ 2.          3.          2.23606798  2.        ]
#  [ 5.          6.          7.81024968  4.        ]
#  [ 4.          7.         25.61249695  5.        ]]

# %% [markdown]
# # Maximum Height of Dendrogram

# %%
plt.figure(figsize=(7,5))

dendrogram(Z)

plt.title("Single Linkage Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")

plt.show()

# Maximum height
max_height = np.max(Z[:,2])

print("\nMaximum Dendrogram Height:", max_height)
# Out:
# Maximum Dendrogram Height: 25.612496949731394
